# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from math import exp, expm1, log
from numpy import amin,amax,zeros,ceil

# %% [markdown]
# Reading data from excel

# %%
Data = pd.read_excel('S&P500.xlsx', usecols="F,G")
Data
# Out:
#             Price      Volume
# 0      987.479980  5139070000
# 1     1002.630005  5603440000
# 2     1005.650024  5713700000
# 3     1002.719971  7242120000
# 4      997.080017  6753380000
# ...           ...         ...
# 2512  3003.669922  3645270000
# 2513  3025.860107  3257590000
# 2514  3020.969971  3203710000
# 2515  3013.179932  3634330000
# 2516  2980.379883  4623430000
#
# [2517 rows x 2 columns]

# %%
x=np.array(Data['Price'])
y=np.array(Data['Volume'])
print(x)
print(y)
# Out:
# [ 987.47998  1002.630005 1005.650024 ... 3020.969971 3013.179932
#  2980.379883]
# [5139070000 5603440000 5713700000 ... 3203710000 3634330000 4623430000]

# %%
h=sns.jointplot(x,y)

# JointGrid has a convenience function
h.set_axis_labels('Price', 'Volume', fontsize=16, fontweight='bold')

# or set labels via the axes objects
#h.ax_joint.set_xlabel('new x label', fontweight='bold')

# also possible to manipulate the histogram plots this way, e.g.
#h.ax_marg_y.grid('on') # with ugly consequences...

# labels appear outside of plot area, so auto-adjust
plt.tight_layout()
# Out:
# C:\Users\Spock\Anaconda3\Anaconda33\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.set()
sns.jointplot(x,y, kind='kde',color="g")

plt.show
# Out:
# C:\Users\Spock\Anaconda3\Anaconda33\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist2d(x,y,30,vmax=10)
plt.xlabel('Price')
plt.ylabel('Volume')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
price_markets=pd.read_excel('S&P500.xlsx', usecols="F")
volume_markets=pd.read_excel('S&P500.xlsx', usecols="G")

# %%
def price_return(price_markets):
    ret=[]
    for i in range(1,len(price_markets)):
        ret.append(log(price_markets.iloc[i])-log(price_markets.iloc[i-1]))
    return ret

# %%
r=price_return(price_markets)

# %%
vol_ret=[]
maxx = np.max(volume_markets["Volume"].values)

for i in range(1,len(volume_markets.values)):
    vol_ret.append(volume_markets["Volume"].values[i]/maxx)
plt.plot(vol_ret,'.')

# %% [markdown]
# # PDF Function

# %% [markdown]
# Things that I need for PDF:
# for partitioning I need the no. and the total length.

# %%
len_x = len(np.array(Data['Price']))
len_y = len(np.array(Data['Volume']))

length_x = max(r) - min(r)
length_y = max(vol_ret) - min(vol_ret)

print(len_x, length_x)
print(len_y, length_y)
# Out:
# 2517 0.11736154688944822
# 2517 0.9034640853433994

# %%
def joint_pdf(data1,data2,delta_x,delta_y):
    dlim_data1 = (min(data1))
    dlim_data2 = (min(data2))
    ulim_data1 = (max(data1))
    ulim_data2 = (max(data2)) 
    
    for i in range (0,len(r)):
        dlim_data1
    return {'pdf':pdf,'x_values':x_values,'y_values':y_values,'dlim':dlim_data1}

# %%
x = min(1000,len(vol_ret))

# %%
x
# Out:
# 1000
